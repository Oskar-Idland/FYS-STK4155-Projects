# %% [markdown]
# # Study of a Regression problem on Franke function

# %%
import matplotlib.pyplot as plt
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import seaborn as sns
plt.rcParams.update({'text.usetex': True, 'font.size': 16, 'font.family': 'serif', 'font.serif': 'Computer Modern Sans Serif', 'font.weight': 100, 'mathtext.fontset': 'cm', 'xtick.labelsize': 14, 'ytick.labelsize': 14})
import warnings

warnings.filterwarnings("ignore")


from utils import *
from activation_funcs import *
from cost_funcs import *
from Schedulers import *
from FFNN import FFNN

plt.style.use('seaborn-darkgrid')

# %%
seed = 42069
np.random.seed(seed)


N  = 25

x = np.linspace(0, 1, N)
y = np.linspace(0, 1, N)
yy, xx = np.meshgrid(x, y)

zz = FrankeFunction(xx, yy, 0.01)
target = zz.reshape(-1,1)


target = (target - np.mean(target)) / np.std(target)

# %%
poly_degree = 4

X = create_X(xx.flatten(), yy.flatten(), poly_degree)

X_train, X_test, z_train, z_test = train_test_split(X, target, test_size=0.2)

scaler_X = StandardScaler()
scaler_z = StandardScaler()
X_train_scaled = scaler_X.fit_transform(X_train)
X_test_scaled = scaler_X.transform(X_test)
z_train_scaled = scaler_z.fit_transform(z_train)
z_test_scaled = scaler_z.transform(z_test)

# %%
# MSE_scores = scores["cost"]
# R2_scores = scores["R2"]
# MSE_test = scores["test_cost"]
# R2_test = scores["test_R2"]

# fig, axs = plt.subplots(1, 2, figsize = (13, 7))
# axs[0].semilogy(MSE_scores, label = "MSE", color="r", linewidth=2)
# axs[0].semilogy(MSE_test, label = "MSE test", color="slateblue", linestyle="--")
# axs[0].set_title("MSE")
# # axs[0].set_yscale('log')  # Set y-axis to log scale

# axs[1].semilogx(R2_scores, label = "R2")
# axs[1].semilogx(R2_test, label = "R2 test", linestyle="--")
# axs[1].set_title("R2")
# # axs[1].set_yscale('log')  # Set y-axis to log scale

# fig.supxlabel("Epoch")

# plt.tight_layout()
# # plt.savefig("../figs/b_train_scores.pdf")
# plt.show()

# %% [markdown]
# ### Initializing the model

# %%
input_shape = X.shape[1]
hidden_shape = [15]
output_shape = 1

dims =  (input_shape, *hidden_shape, output_shape)

model = FFNN(
			layer_sizes=dims,
			hidden_funcs=[sigmoid],
			output_func=identity,
			cost_func=MSE,
			cost_der=MSE_derivative,
			seed=seed
		)

# %% [markdown]
# - Discuss why we set the same hidden layers for all models

# %% [markdown]
# # Finding optimal hidden layer parameters

# %% [markdown]
# ## Plotting epoch vs batch size

# %%
scheduler = AdagradMomentum(eta=0.15, momentum=0.8)
lmbda = 0.001

epochs_list = [100, 500, 1000, 2000]
batches_list = [1, 10, 20, 50, 100]

MSE_scores_1 = np.zeros([len(epochs_list), len(batches_list)])
R2_scores_1 = np.zeros([len(epochs_list), len(batches_list)])
MSE_test_1 = np.zeros([len(epochs_list), len(batches_list)])
R2_test_1 = np.zeros([len(epochs_list), len(batches_list)])

for i, n_epochs in enumerate(epochs_list):
	for j, n_batches in enumerate(batches_list):
		model.reset_weights()

		scores = model.fit(
			X_train_scaled,
			z_train_scaled, 
			scheduler=scheduler,
			epochs=n_epochs,
			batches= n_batches,
			lmbda=lmbda,
			X_test=X_test_scaled,
			y_test=z_test_scaled,
			)
		print(f"Training model with {n_epochs} epochs and {n_batches} batches\n")
		# Store the final value
		MSE_scores_1[i][j] = scores["cost"][-1]
		R2_scores_1[i][j] = scores["R2"][-1]

		MSE_test_1[i][j] = scores["test_cost"][-1]
		R2_test_1[i][j] = scores["test_R2"][-1]
# Out:
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.303 | R2_test: 0.636 | test_scores: 0.352 | R2_scores: 0.697 0  Training model with 100 epochs and 1 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0547 | R2_test: 0.944 | test_scores: 0.0543 | R2_scores: 0.945 Training model with 100 epochs and 10 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0426 | R2_test: 0.960 | test_scores: 0.0383 | R2_scores: 0.957 Training model with 100 epochs and 20 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0373 | R2_test: 0.959 | test_scores: 0.0395 | R2_scores: 0.963 Training model with 100 epochs and 50 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0614 | R2_test: 0.947 | test_scores: 0.0510 | R2_scores: 0.939 Training model with 100 epochs and 100 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.193 | R2_test: 0.829 | test_scores: 0.165 | R2_scores: 0.807    Training model with 500 epochs and 1 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0668 | R2_test: 0.917 | test_scores: 0.0798 | R2_scores: 0.933 Training model with 500 epochs and 10 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0550 | R2_test: 0.942 | test_scores: 0.0561 | R2_scores: 0.945  Training model with 500 epochs and 20 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0447 | R2_test: 0.955 | test_scores: 0.0434 | R2_scores: 0.955  Training model with 500 epochs and 50 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0672 | R2_test: 0.929 | test_scores: 0.0684 | R2_scores: 0.933  Training model with 500 epochs and 100 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.120 | R2_test: 0.905 | test_scores: 0.0922 | R2_scores: 0.880   Training model with 1000 epochs and 1 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0708 | R2_test: 0.917 | test_scores: 0.0800 | R2_scores: 0.929 Training model with 1000 epochs and 10 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0448 | R2_test: 0.959 | test_scores: 0.0401 | R2_scores: 0.955  Training model with 1000 epochs and 20 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0672 | R2_test: 0.937 | test_scores: 0.0612 | R2_scores: 0.933  Training model with 1000 epochs and 50 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0723 | R2_test: 0.928 | test_scores: 0.0692 | R2_scores: 0.928  Training model with 1000 epochs and 100 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.119 | R2_test: 0.905 | test_scores: 0.0917 | R2_scores: 0.881   Training model with 2000 epochs and 1 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0599 | R2_test: 0.940 | test_scores: 0.0581 | R2_scores: 0.940  Training model with 2000 epochs and 10 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0432 | R2_test: 0.962 | test_scores: 0.0368 | R2_scores: 0.957  Training model with 2000 epochs and 20 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0627 | R2_test: 0.929 | test_scores: 0.0682 | R2_scores: 0.937  Training model with 2000 epochs and 50 batches
#
# AdagradMomentum: Eta=0.15, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0690 | R2_test: 0.933 | test_scores: 0.0643 | R2_scores: 0.931   Training model with 2000 epochs and 100 batches

# %%
fig, axs = gridsearch_plot((MSE_test_1, R2_test_1), (batches_list, epochs_list), "GnBu", ("min", "max"), fmt2=".2%")

fig.suptitle("Neural network performance as a function of number of batches and epochs")
axs[0].set_title("Mean Squared Error")
axs[1].set_title("R² Score (\%)")
axs[0].set_ylabel("Number of epochs") 
fig.supxlabel("Number of batches")
plt.tight_layout()
plt.savefig("../figs/c_batch_epoch.pdf")
plt.show()

# %% [markdown]
# ## Finding optimal learning rate and regularization parameter

# %%
epochs = 500
batches = 20

etas_list = [0.0001, 0.001, 0.01, 0.1, 0.5,]
lmbdas_list = [0.00001, 0.0001, 0.001, 0.01, 0.1]

MSE_scores_2 = np.zeros([len(etas_list), len(lmbdas_list)])
R2_scores_2 = np.zeros([len(etas_list), len(lmbdas_list)])
MSE_test_2 = np.zeros([len(etas_list), len(lmbdas_list)])
R2_test_2 = np.zeros([len(etas_list), len(lmbdas_list)])

for i, n_eta in enumerate(etas_list):
	for j, n_lmbda in enumerate(lmbdas_list):
		model.reset_weights()
		scheduler = AdagradMomentum(eta=n_eta, momentum=0.8)
		scores = model.fit(
			X_train_scaled,
			z_train_scaled, 
			scheduler=scheduler,
			epochs=epochs,
			batches=batches,
			lmbda=n_lmbda,
			X_test=X_test_scaled,
			y_test=z_test_scaled,
			)
		print(f"\n")

		
		# Store the final value
		MSE_scores_2[i][j] = scores["cost"][-1]
		R2_scores_2[i][j] = scores["R2"][-1]
		MSE_test_2[i][j] = scores["test_cost"][-1]
		R2_test_2[i][j] = scores["test_R2"][-1]
# Out:
# AdagradMomentum: Eta=0.0001, Lambda=1e-05
#   [=======================================>] 100.0% | training_scores: 0.106 | R2_test: 0.900 | test_scores: 0.0968 | R2_scores: 0.894  1
#
# AdagradMomentum: Eta=0.0001, Lambda=0.0001
#   [=======================================>] 100.0% | training_scores: 0.106 | R2_test: 0.900 | test_scores: 0.0968 | R2_scores: 0.894  1
#
# AdagradMomentum: Eta=0.0001, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.107 | R2_test: 0.899 | test_scores: 0.0974 | R2_scores: 0.893  2
#
# AdagradMomentum: Eta=0.0001, Lambda=0.01
#   [=======================================>] 100.0% | training_scores: 0.119 | R2_test: 0.887 | test_scores: 0.109 | R2_scores: 0.881
#
# AdagradMomentum: Eta=0.0001, Lambda=0.1
#   [=======================================>] 100.0% | training_scores: 0.238 | R2_test: 0.763 | test_scores: 0.229 | R2_scores: 0.762
#
# AdagradMomentum: Eta=0.001, Lambda=1e-05
#   [=======================================>] 100.0% | training_scores: 0.0219 | R2_test: 0.979 | test_scores: 0.0205 | R2_scores: 0.978
#
# AdagradMomentum: Eta=0.001, Lambda=0.0001
#   [=======================================>] 100.0% | training_scores: 0.0228 | R2_test: 0.978 | test_scores: 0.0211 | R2_scores: 0.977
#
# AdagradMomentum: Eta=0.001, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0338 | R2_test: 0.969 | test_scores: 0.0300 | R2_scores: 0.966
#
# AdagradMomentum: Eta=0.001, Lambda=0.01
#   [=======================================>] 100.0% | training_scores: 0.114 | R2_test: 0.888 | test_scores: 0.108 | R2_scores: 0.886  3
#
# AdagradMomentum: Eta=0.001, Lambda=0.1
#   [=======================================>] 100.0% | training_scores: 0.283 | R2_test: 0.707 | test_scores: 0.283 | R2_scores: 0.717
#
# AdagradMomentum: Eta=0.01, Lambda=1e-05
#   [=======================================>] 100.0% | training_scores: 0.00645 | R2_test: 0.992 | test_scores: 0.00759 | R2_scores: 0.994
#
# AdagradMomentum: Eta=0.01, Lambda=0.0001
#   [=======================================>] 100.0% | training_scores: 0.00692 | R2_test: 0.991 | test_scores: 0.00869 | R2_scores: 0.993
#
# AdagradMomentum: Eta=0.01, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0169 | R2_test: 0.983 | test_scores: 0.0161 | R2_scores: 0.983
#
# AdagradMomentum: Eta=0.01, Lambda=0.01
#   [=======================================>] 100.0% | training_scores: 0.111 | R2_test: 0.905 | test_scores: 0.0914 | R2_scores: 0.889
#
# AdagradMomentum: Eta=0.01, Lambda=0.1
#   [=======================================>] 100.0% | training_scores: 0.282 | R2_test: 0.722 | test_scores: 0.269 | R2_scores: 0.718
#
# AdagradMomentum: Eta=0.1, Lambda=1e-05
#   [=======================================>] 100.0% | training_scores: 0.0177 | R2_test: 0.983 | test_scores: 0.0167 | R2_scores: 0.982 1
#
# AdagradMomentum: Eta=0.1, Lambda=0.0001
#   [=======================================>] 100.0% | training_scores: 0.0309 | R2_test: 0.962 | test_scores: 0.0371 | R2_scores: 0.969
#
# AdagradMomentum: Eta=0.1, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.0324 | R2_test: 0.965 | test_scores: 0.0336 | R2_scores: 0.968
#
# AdagradMomentum: Eta=0.1, Lambda=0.01
#   [=======================================>] 100.0% | training_scores: 0.117 | R2_test: 0.866 | test_scores: 0.130 | R2_scores: 0.883
#
# AdagradMomentum: Eta=0.1, Lambda=0.1
#   [=======================================>] 100.0% | training_scores: 0.336 | R2_test: 0.641 | test_scores: 0.347 | R2_scores: 0.664
#
# AdagradMomentum: Eta=0.5, Lambda=1e-05
#   [=======================================>] 100.0% | training_scores: 0.396 | R2_test: 0.593 | test_scores: 0.394 | R2_scores: 0.604 060
#
# AdagradMomentum: Eta=0.5, Lambda=0.0001
#   [=======================================>] 100.0% | training_scores: 0.591 | R2_test: 0.506 | test_scores: 0.477 | R2_scores: 0.409 9
#
# AdagradMomentum: Eta=0.5, Lambda=0.001
#   [=======================================>] 100.0% | training_scores: 0.875 | R2_test: 0.118 | test_scores: 0.852 | R2_scores: 0.125 9
#
# AdagradMomentum: Eta=0.5, Lambda=0.01
#   [=======================================>] 100.0% | training_scores: 0.640 | R2_test: 0.367 | test_scores: 0.611 | R2_scores: 0.360 2 8
#
# AdagradMomentum: Eta=0.5, Lambda=0.1
#   [=======================================>] 100.0% | training_scores: 0.519 | R2_test: 0.450 | test_scores: 0.532 | R2_scores: 0.481 018

# %%
fig, axs = gridsearch_plot((MSE_test_2, R2_test_2), (lmbdas_list, etas_list), "GnBu", ("min", "max"), fmt2=".2%")

fig.suptitle("Neural network performance as a function of learning rate and regularization parameter")
axs[0].set_title("Mean Squared Error")
axs[1].set_title("R² Score (\%)")
axs[0].set_ylabel(r"$\eta$ value")
fig.supxlabel(r"$\lambda$ value")
plt.tight_layout()
# plt.savefig("../figs/c_eta_lambda.pdf")
plt.show()

# %% [markdown]
# ## Testing different schedulers

# %%
epochs = 500
batches = 20

lmbda = 0.0001

eta= 0.001
gamma= 0.8
rho= 0.9
rho2= 0.999

schedulers = [
	Constant(eta=eta),
	Momentum(eta=eta, momentum=gamma),
	Adagrad(eta=eta),
	AdagradMomentum(eta=eta, momentum=gamma),
	Adam(eta=eta, rho=rho, rho2=rho2),
	RMS_prop(eta=eta, rho=rho),
]

# Initialize arrays to store the results
scheduler_names = ["Constant", "Momentum", "Adagrad", "AdagradMomentum", "Adam", "RMSprop"]
MSE_scores_schedulers = np.zeros([len(schedulers), epochs])
R2_scores_schedulers = np.zeros([len(schedulers), epochs])
convergence_epochs = np.zeros([len(schedulers)])	

# Loop over each scheduler and evaluate the model
for i, scheduler in enumerate(schedulers):
	model.reset_weights()
	scores, convergence_epochs[i] = model.fit(
		X_train_scaled,
		z_train_scaled, 
		scheduler=scheduler,
		epochs=epochs,
		batches=batches,
		lmbda=lmbda,
		convergence_tol=1e-2
	)
	
	# Store the final value
	MSE_scores_schedulers[i,:] = scores["cost"]
	R2_scores_schedulers[i,:] = scores["R2"]

	print(f"Training model with {scheduler_names[i]} scheduler\n")
# Out:
# Constant: Eta=0.001, Lambda=0.0001
#   [============>---------------------------] 34.80% | training_scores: 0.223 | R2_scores: 0.777
# Converged at epoch 174 with MSE stability below 1.00e-02
#   [=======================================>] 100.0% | training_scores: 0.140 | R2_scores: 0.860 Training model with Constant scheduler
#
# Momentum: Eta=0.001, Lambda=0.0001
#   [==============>-------------------------] 39.00% | training_scores: 0.103 | R2_scores: 0.897
# Converged at epoch 195 with MSE stability below 1.00e-02
#   [=======================================>] 100.0% | training_scores: 0.0708 | R2_scores: 0.929 Training model with Momentum scheduler
#
# Adagrad: Eta=0.001, Lambda=0.0001
#   [=================>----------------------] 47.40% | training_scores: 0.0536 | R2_scores: 0.946
# Converged at epoch 237 with MSE stability below 1.00e-02
#   [=======================================>] 100.0% | training_scores: 0.0328 | R2_scores: 0.967 Training model with Adagrad scheduler
#
# AdagradMomentum: Eta=0.001, Lambda=0.0001
#   [===========>----------------------------] 30.20% | training_scores: 0.0595 | R2_scores: 0.940
# Converged at epoch 151 with MSE stability below 1.00e-02
#   [=======================================>] 100.0% | training_scores: 0.0228 | R2_scores: 0.977 Training model with AdagradMomentum scheduler
#
# Adam: Eta=0.001, Lambda=0.0001
#   [=====>----------------------------------] 16.00% | training_scores: 0.0563 | R2_scores: 0.944
# Converged at epoch 80 with MSE stability below 1.00e-02
#   [=======================================>] 100.0% | training_scores: 0.00366 | R2_scores: 0.996 Training model with Adam scheduler
#
# RMS_prop: Eta=0.001, Lambda=0.0001
#   [=======>--------------------------------] 21.40% | training_scores: 0.0409 | R2_scores: 0.959
# Converged at epoch 107 with MSE stability below 1.00e-02
#   [=======================================>] 100.0% | training_scores: 0.00666 | R2_scores: 0.993 Training model with RMSprop scheduler

# %%
from mpl_toolkits.axes_grid1.inset_locator import inset_axes, mark_inset

fig, axs = plt.subplots(1, 2, figsize=(15, 5))
colors = sns.color_palette(n_colors=len(schedulers))

# Create inset axes
axins2 = inset_axes(axs[1], width="60%", height="60%", bbox_to_anchor=(0.1, -0.15, 0.8, 0.75), bbox_transform=axs[1].transAxes)

# Plot MSE scores
for i, scheduler_name in enumerate(scheduler_names):
    # Main plot
    axs[0].semilogy(range(epochs), MSE_scores_schedulers[i], color=colors[i])
    axs[0].scatter(convergence_epochs[i], MSE_scores_schedulers[i, int(convergence_epochs[i])], 
                  marker='x', color=colors[i], s=100)

axs[0].set_title("MSE Scores vs Epochs")
axs[0].set_xlabel("Epochs")
axs[0].set_ylabel("MSE")

# Plot R² scores
for i, scheduler_name in enumerate(scheduler_names):
    # Main plot
    axs[1].plot(range(epochs), R2_scores_schedulers[i], label=scheduler_name, color=colors[i])
    # Inset plot
    axins2.plot(range(epochs), R2_scores_schedulers[i], color=colors[i])

axs[1].set_yticks(np.arange(-4, 1.1, 1))
axs[1].set_yticklabels([f"{int(i*100)}%" for i in np.arange(-4, 1.1, 1)])
axs[1].set_title("R² Scores vs Epochs")
axs[1].set_xlabel("Epochs")
axs[1].set_ylabel("R² (\%)")
axs[0].legend(loc="upper right")


axins2.set_xlim(-10, 200)  
axins2.set_ylim(0, 1.2)  
axins2.grid(True)


axins2.set_xticks(np.arange(0, 210, 50))
axins2.set_xticklabels([f"{int(i)}" for i in np.arange(0, 210, 50)])
axins2.set_yticks(np.arange(0, 1.1, .2))
axins2.set_yticklabels([f"{int(i*100)}%" for i in np.arange(0, 1.1, .2)])

axins2.set_title("Zoomed in")
axins2.set_facecolor('white')
axins2.patch.set_alpha(0.3)
for spine in axins2.spines.values():
    spine.set_edgecolor('gray')
    spine.set_linewidth(1)

# Add connecting lines
mark_inset(axs[1], axins2, loc1=1, loc2=3, fc="none", ec="0.5")

fig.legend(bbox_to_anchor=(.1, -0.01), 
          loc='center left',
          ncol=len(schedulers),
          title="Schedulers",
          borderaxespad=0)

fig.suptitle("Neural network performance as a scheduler")
plt.tight_layout()
plt.subplots_adjust(bottom=0.2)
plt.savefig("../figs/b_schedulers.pdf", bbox_inches='tight')
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# ## Testing different activation functions

# %%
input_shape = X.shape[1]
hidden_shape = [15]
output_shape = 1

dims =  (input_shape, *hidden_shape, output_shape)

epochs = 500
batches = 20

lmbda = 0.0001

eta= 0.001
gamma= 0.8
scheduler = AdagradMomentum(eta=eta, momentum=gamma)

# Initialize arrays to store the results
activation_funcs = [identity, sigmoid, RELU, LRELU]
activation_funcs_names = ["Identity", "Sigmoid", "RELU", "LRELU"]

MSE_scores_schedulers = np.zeros(len(activation_funcs))
R2_scores_schedulers = np.zeros(len(activation_funcs))
MSE_test_activatons	= np.zeros(len(activation_funcs))
R2_test_activations = np.zeros(len(activation_funcs))

# Loop over each scheduler and evaluate the model
for i, activation_func in enumerate(activation_funcs):
	model = FFNN(
				layer_sizes=dims,
				hidden_funcs=[activation_func],
				output_func=identity,
				cost_func=MSE,
				cost_der=MSE_derivative,
				seed=seed
			)
	
	scores = model.fit(
		X_train_scaled,
		z_train_scaled, 
		scheduler=scheduler,
		epochs=epochs,
		batches=batches,
		lmbda=lmbda,
		X_test=X_test_scaled,
		y_test=z_test_scaled,
	)
	
	# Store the final value
	MSE_scores_schedulers[i] = scores["cost"][-1]
	R2_scores_schedulers[i] = scores["R2"][-1]
	MSE_test_activatons[i] = scores["test_cost"][-1]
	R2_test_activations[i] = scores["test_R2"][-1]

	print(f"Training model with {activation_funcs_names[i]} scheduler\n")
# Out:
# AdagradMomentum: Eta=0.001, Lambda=0.0001
#   [=======================================>] 100.0% | training_scores: 0.116 | R2_test: 0.895 | test_scores: 0.102 | R2_scores: 0.884  Training model with Identity scheduler
#
# AdagradMomentum: Eta=0.001, Lambda=0.0001
#   [=======================================>] 100.0% | training_scores: 0.0228 | R2_test: 0.978 | test_scores: 0.0211 | R2_scores: 0.977  Training model with Sigmoid scheduler
#
# AdagradMomentum: Eta=0.001, Lambda=0.0001
#   [=======================================>] 100.0% | training_scores: 0.0246 | R2_test: 0.971 | test_scores: 0.0284 | R2_scores: 0.975 Training model with RELU scheduler
#
# AdagradMomentum: Eta=0.001, Lambda=0.0001
#   [=======================================>] 100.0% | training_scores: 0.0242 | R2_test: 0.971 | test_scores: 0.0278 | R2_scores: 0.976 Training model with LRELU scheduler

# %%
fig, axs = plt.subplots(1, 2, figsize=(13, 5))

activation_results = {
    'Activation Function': activation_funcs_names,
    'MSE': MSE_test_activatons,
    'R2': R2_test_activations
}

sns.barplot(
    y="MSE",
    x="Activation Function",
    data=activation_results,
    palette="husl",
    ax=axs[0]
)

for i, v in enumerate(activation_results['MSE']):
    axs[0].text(i, v, f'{v:.3f}', ha='center', va='bottom')

sns.barplot(
    y="R2",
    x="Activation Function",
    data=activation_results,
    palette="husl",
    ax=axs[1]
)

# Add value labels for R2
for i, v in enumerate(activation_results['R2']):
    axs[1].text(i, v, f'{v:.3f}', ha='center', va='bottom')

axs[0].set_title("MSE")
axs[1].set_title("R²")

axs[0].set_xlabel("")
axs[0].set_ylabel("")
axs[1].set_xlabel("")
axs[1].set_ylabel("")

axs[0].set_ylim(0, max(MSE_test_activatons) + .05)
axs[1].set_ylim(0, max(R2_test_activations) + .05)
fig.suptitle("Scores for Different Activation Functions")
fig.supxlabel("Activation Function")
plt.tight_layout()
# plt.savefig("../figs/c_activation_funcs.pdf")
plt.show()

# %% [markdown]
# # Appendix: Fiding our standard model

# %%
seed = 42069
np.random.seed(seed)


N_list  = [100]
hidden_layers = [1,2]
hidden_nodes = [10, 15, 30]

poly_degrees = 4
epochs = 500
batches = 50

lmbda = 0.0001
eta= 0.001

scheduler = Adam(eta=eta, rho=0.9, rho2=0.999)

MSE_train = np.zeros([len(N_list), len(hidden_layers), len(hidden_nodes)])
R2_train = np.zeros([len(N_list), len(hidden_layers), len(hidden_nodes)])
MSE_test = np.zeros([len(N_list), len(hidden_layers), len(hidden_nodes)])
R2_test = np.zeros([len(N_list), len(hidden_layers), len(hidden_nodes)])

for i, N in enumerate(N_list):
	x = np.linspace(0, 1, N)
	y = np.linspace(0, 1, N)
	yy, xx = np.meshgrid(x, y)

	zz = FrankeFunction(xx, yy)
	# target = zz.reshape(-1,1)
	target = (zz + 0.001*np.random.randn(N,N)).reshape(-1,1)

	target = (target - np.mean(target)) / np.std(target)

	X = create_X(xx.flatten(), yy.flatten(), poly_degree)

	X_train, X_test, z_train, z_test = train_test_split(X, target, test_size=0.2)

	scaler_X = StandardScaler()
	scaler_z = StandardScaler()
	X_train_scaled = scaler_X.fit_transform(X_train)
	X_test_scaled = scaler_X.transform(X_test)
	z_train_scaled = scaler_z.fit_transform(z_train)
	z_test_scaled = scaler_z.transform(z_test)

	for j, hidden_layer in enumerate(hidden_layers):
		for k, hidden_node in enumerate(hidden_nodes):
			input_shape = X.shape[1]
			hidden_shape = [hidden_node]*hidden_layer
			output_shape = 1
			dims =  (input_shape, *hidden_shape, output_shape)

			model = FFNN(
						layer_sizes=dims,
						hidden_funcs=[sigmoid]*hidden_layer,
						output_func=identity,
						cost_func=MSE,
						cost_der=MSE_derivative,
						seed=seed
					)

			scores = model.fit(
				X_train_scaled,
				z_train_scaled, 
				scheduler=scheduler,
				epochs=epochs,
				batches=batches,
				lmbda=lmbda,
				X_test=X_test_scaled,
				y_test=z_test_scaled,
			)

			print(f"Training model with N={N}, hidden_layer={hidden_layer}, hidden_node={hidden_node}\n")

			MSE_train[i][j][k] = scores["cost"][-1]
			R2_train[i][j][k] = scores["R2"][-1]
			MSE_test[i][j][k] = scores["test_cost"][-1]
			R2_test[i][j][k] = scores["test_R2"][-1]
# Out:
# Adam: Eta=0.001, Lambda=0.0001
#   [=======================================>] 100.0% | training_scores: 0.00214 | R2_test: 0.998 | test_scores: 0.00229 | R2_scores: 0.998 Training model with N=100, hidden_layer=1, hidden_node=10
#
# Adam: Eta=0.001, Lambda=0.0001
#   [=======================================>] 100.0% | training_scores: 0.00103 | R2_test: 0.999 | test_scores: 0.00103 | R2_scores: 0.999 Training model with N=100, hidden_layer=1, hidden_node=15
#
# Adam: Eta=0.001, Lambda=0.0001
#   [=======================================>] 100.0% | training_scores: 0.000923 | R2_test: 0.999 | test_scores: 0.000911 | R2_scores: 0.999 Training model with N=100, hidden_layer=1, hidden_node=30
#
# Adam: Eta=0.001, Lambda=0.0001
#   [=======================================>] 100.0% | training_scores: 0.00123 | R2_test: 0.999 | test_scores: 0.00129 | R2_scores: 0.999 Training model with N=100, hidden_layer=2, hidden_node=10
#
# Adam: Eta=0.001, Lambda=0.0001
#   [=======================================>] 100.0% | training_scores: 0.000827 | R2_test: 0.999 | test_scores: 0.000846 | R2_scores: 0.999 Training model with N=100, hidden_layer=2, hidden_node=15
#
# Adam: Eta=0.001, Lambda=0.0001
#   [=======================================>] 100.0% | training_scores: 0.000518 | R2_test: 0.999 | test_scores: 0.000536 | R2_scores: 0.999 Training model with N=100, hidden_layer=2, hidden_node=30

# %%
# Create figure with subplots for train and test scores
fig, axes = plt.subplots(len(N_list),2, figsize=(9, 3))
fig.suptitle('MSE Scores: Training vs Test', fontsize=16, y=1.05)

for i, N in enumerate(N_list):
    # Training scores
    sns.heatmap(
        MSE_train[i, :, :],
        annot=True,
        fmt='.3f',
        cmap='YlOrRd',
        xticklabels=hidden_nodes,
        yticklabels=hidden_layers,
        ax=axes[0],
        cbar=False
    )
    axes[0].set_xlabel('Hidden Nodes')
    axes[0].set_ylabel('Hidden Layers' if i == 0 else '')
    axes[0].set_title(f'Training MSE (N={N})')
    
    # Test scores
    sns.heatmap(
        MSE_test[i, :, :],
        annot=True,
        fmt='.3f',
        cmap='YlOrRd',
        xticklabels=hidden_nodes,
        yticklabels=hidden_layers,
        ax=axes[1],
        cbar=False
    )
    axes[1].set_xlabel('Hidden Nodes')
    axes[1].set_title(f'Test MSE (N={N})')

plt.tight_layout()
plt.savefig("../figs/standard_model.pdf")
plt.show()

# %% [markdown]
# ## Plotting the optimal model

# %%
input_shape = X.shape[1]
hidden_shape = [15]
output_shape = 1
dims =  (input_shape, *hidden_shape, output_shape)

model = FFNN(
	layer_sizes=dims,
	hidden_funcs=[sigmoid],
	output_func=identity,
	cost_func=MSE,
	cost_der=MSE_derivative,
	seed=seed
)

scheduler = Adam(eta=0.001, rho=0.9, rho2=0.999)

epochs = 1000
batches = 20

lmbda = 0.001

scores = model.fit(
	X_train_scaled,
	z_train_scaled, 
	scheduler=scheduler,
	epochs=epochs,
	batches=batches,
	lmbda=lmbda,
	X_test=X_test_scaled,
	y_test=z_test_scaled,
	)

# %%
z_pred = model.predict(X_test_scaled)
z_pred = scaler_z.inverse_transform(z_pred)

grid_size = int(np.sqrt(len(z_pred)))
xx = xx.reshape((100, 100))
yy = yy.reshape((100, 100))
zz = zz.reshape((grid_size, grid_size))
z_pred = z_pred.reshape((grid_size, grid_size))

fig = plt.figure(figsize = (13, 7))
axs = [fig.add_subplot(121, projection = "3d"), fig.add_subplot(122, projection = "3d")]

surf_true = axs[0].plot_surface(xx, yy, zz, cmap = cm.coolwarm, linewidth = 0, antialiased = False)
axs[0].set_title("True Franke function")
axs[1].set_title("Predicted Franke function")
surf_predict = axs[1].plot_surface( z_pred, cmap = cm.coolwarm, linewidth = 0, antialiased = False)
for i in range(2):
	axs[i].zaxis.set_major_locator(LinearLocator(10))
	axs[i].zaxis.set_major_formatter(FormatStrFormatter("%.02f"))
	axs[i].set_xlabel(r"$x$")
	axs[i].set_ylabel(r"$y$")
fig.colorbar(surf_true, shrink = 0.4, aspect = 10, label = r"$f(x,y)$")
fig.colorbar(surf_predict, shrink = 0.4, aspect = 10, label = r"$f(x,y)+\varepsilon$")
plt.tight_layout()
# plt.savefig("../figs/a_Franke_surf.pdf")
plt.show()
